# %% [markdown]
# <a href="https://colab.research.google.com/github/nilsroemertum/synlab-slim-viewer/blob/master/notebooks/dev_deploy_gc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
gcpProjectID = 'synlab-pacs-workflow'
gcpClientID = '"62039621046-rt1fu02rnnfrlf2icjh2q1cmervka8au.apps.googleusercontent.com"'
FirebaseProjectName = 'synlab-pacs-slim-viewer'

# !npm install -g yarn
# !curl -sL https://firebase.tools | bash
# !git clone https://github.com/nilsroemertum/synlab-slim-viewer.git
# !npm install -g n
# !n install 24 && n 24
# !cd synlab-slim-viewer && yarn

settings = """
window.config = {
  // This must match the location configured for web server
  path: '/',
  servers: [
    {
      id: 'example',
      // This must match the proxy location configured for the DICOMweb server
      url:"https://healthcare.googleapis.com/v1/projects/synlab-pacs-workflow/locations/europe-west3/datasets/synlab-healthcare-dataset/dicomStores/synlab-dicom-data-store/dicomWeb",
      write: false
    }
  ],
 oidc: {
    authority: "https://accounts.google.com",
    clientId: %s,
    scope: "email profile openid https://www.googleapis.com/auth/cloud-healthcare",
    grantType: "implicit"
  },
  disableWorklist: false,
  disableAnnotationTools: false,
  showLeftCaseSider: true,
  showRightSlideViewerSidebar: true,
  showHeaderInSlideViewer: true,
  enableServerSelection: true,
  mode: 'light',
  preload: true,
  annotations: []
}
"""%(gcpClientID)

with open("synlab-slim-viewer/public/config/example.js", "w") as f:
    f.write(settings)

settings_firebase = """
{
  "hosting": {
    "public": "build",
    "ignore": [
      "firebase.json",
      "**/.*",
      "**/node_modules/**"
    ],
    "rewrites": [
      {
        "source": "**",
        "destination": "/index.html"
      }
    ]
  }
}
"""

with open("synlab-slim-viewer/firebase.json", "w") as f:
  f.write(settings_firebase)

# !cd synlab-slim-viewer && REACT_APP_CONFIG=example PUBLIC_URL='/' yarn build
# !firebase login --no-localhost
# !gcloud auth login
# !gcloud config set project $gcpProjectID
# !gcloud config get project
# !firebase projects:list
# !cd synlab-slim-viewer && firebase use $FirebaseProjectName && firebase deploy
# Out:
# ⠙⠹⠸⠼
# changed 1 package in 474ms
# ⠼-- Checking for existing firebase-tools...
# Your machine has firebase-tools@14.16.0 installed.
# If you would like to upgrade your install run: curl -sL firebase.tools | upgrade=true bash
# fatal: destination path 'synlab-slim-viewer' already exists and is not an empty directory.
# ⠙
# changed 1 package in 263ms
# ⠙     copying : node/24.8.0
#    installed : v24.8.0 (with npm 11.6.0)
#      copying : node/24.8.0
#    installed : v24.8.0 (with npm 11.6.0)
# yarn install v1.22.22
# [1/4] Resolving packages...
# warning Resolution field "semver@7.5.2" is incompatible with requested version "semver@^7.6.0"
# warning Resolution field "semver@7.5.2" is incompatible with requested version "semver@^7.5.3"
# warning Resolution field "wrap-ansi@7.0.0" is incompatible with requested version "wrap-ansi@^8.1.0"
# warning Resolution field "make-dir@3.1.0" is incompatible with requested version "make-dir@^2.1.0"
has unmet peer dependency "@babel/core@^7.0.0-0".
# warning "@babel/preset-env > babel-plugin-polyfill-regenerator@0.4.1" has unmet peer dependency "@babel/core@^7.0.0-0".
# warning "@babel/preset-env > @babel/plugin-proposal-async-generator-functions > @babel/helper-remap-async-to-generator@7.18.9" has unmet peer dependency "@babel/core@^7.0.0".
# warning "@babel/preset-env > @babel/plugin-proposal-class-properties > @babel/helper-create-class-features-plugin@7.20.5" has unmet peer dependency "@babel/core@^7.0.0".
# warning "@babel/preset-env > @babel/plugin-proposal-unicode-property-regex > @babel/helper-create-regexp-features-plugin@7.20.5" has unmet peer dependency "@babel/core@^7.0.0".
# warning "@babel/preset-env > babel-plugin-polyfill-corejs2 > @babel/helper-define-polyfill-provider@0.3.3" has unmet peer dependency "@babel/core@^7.4.0-0".
# warning " > @babel/preset-react@7.18.6" has unmet peer dependency "@babel/core@^7.0.0-0".
# warning "@babel/preset-react > @babel/plugin-transform-react-display-name@7.18.6" has unmet peer dependency "@babel/core@^7.0.0-0".
# warning "@babel/preset-react > @babel/plugin-transform-react-jsx@7.19.0" has unmet peer dependency "@babel/core@^7.0.0-0".
# warning "@babel/preset-react > @babel/plugin-transform-react-jsx-development@7.18.6" has unmet peer dependency "@babel/core@^7.0.0-0".
# warning "@babel/preset-react > @babel/plugin-transform-react-pure-annotations@7.18.6" has unmet peer dependency "@babel/core@^7.0.0-0".
# warning "@babel/preset-react > @babel/plugin-transform-react-jsx > @babel/plugin-syntax-jsx@7.18.6" has unmet peer dependency "@babel/core@^7.0.0-0".
# warning " > @babel/preset-typescript@7.18.6" has unmet peer dependency "@babel/core@^7.0.0-0".
# warning "@babel/preset-typescript > @babel/plugin-transform-typescript@7.20.2" has unmet peer dependency "@babel/core@^7.0.0-0".
# warning "@babel/preset-typescript > @babel/plugin-transform-typescript > @babel/plugin-syntax-typescript@7.20.0" has unmet peer dependency "@babel/core@^7.0.0-0".
# warning " > @craco/craco@6.4.5" has incorrect peer dependency "react-scripts@^4.0.0".
# warning " > @semantic-release/changelog@6.0.3" has unmet peer dependency "semantic-release@>=18.0.0".
# warning " > @semantic-release/commit-analyzer@12.0.0" has unmet peer dependency "semantic-release@>=20.1.0".
# warning " > @semantic-release/git@10.0.1" has unmet peer dependency "semantic-release@>=18.0.0".
# warning " > @semantic-release/github@10.0.3" has unmet peer dependency "semantic-release@>=20.1.0".
# warning " > @semantic-release/npm@12.0.0" has unmet peer dependency "semantic-release@>=20.1.0".
# warning " > @semantic-release/release-notes-generator@13.0.0" has unmet peer dependency "semantic-release@>=20.1.0".
# warning " > @testing-library/user-event@7.2.1" has unmet peer dependency "@testing-library/dom@>=5".
# warning " > copy-webpack-plugin@10.2.4" has unmet peer dependency "webpack@^5.1.0".
# warning "craco-less > less-loader@7.3.0" has unmet peer dependency "webpack@^4.0.0 || ^5.0.0".
# warning "react-scripts > eslint-config-react-app > eslint-plugin-flowtype@8.0.3" has unmet peer dependency "@babel/plugin-syntax-flow@^7.14.5".
# warning "react-scripts > eslint-config-react-app > eslint-plugin-flowtype@8.0.3" has unmet peer dependency "@babel/plugin-transform-react-jsx@^7.14.9".
# warning "react-scripts > workbox-webpack-plugin > workbox-build > @rollup/plugin-babel@5.3.1" has incorrect peer dependency "rollup@^1.20.0||^2.0.0".
# warning "react-scripts > workbox-webpack-plugin > workbox-build > @rollup/plugin-node-resolve@11.2.1" has incorrect peer dependency "rollup@^1.20.0||^2.0.0".
# warning "react-scripts > workbox-webpack-plugin > workbox-build > @rollup/plugin-replace@2.4.2" has incorrect peer dependency "rollup@^1.20.0 || ^2.0.0".
# warning "react-scripts > workbox-webpack-plugin > workbox-build > rollup-plugin-terser@7.0.2" has incorrect peer dependency "rollup@^2.0.0".
# warning "react-scripts > workbox-webpack-plugin > workbox-build > @rollup/plugin-babel > @rollup/pluginutils@3.1.0" has incorrect peer dependency "rollup@^1.20.0||^2.0.0".
# warning "ts-standard > @typescript-eslint/eslint-plugin@4.33.0" has unmet peer dependency "@typescript-eslint/parser@^4.0.0".
# warning Workspaces can only be enabled in private projects.
# [] 0/2027[] 0/164[] 128/164[] 164/164[] 0/3480[] 498/3480[] 946/3480[] 1242/3480[] 1778/3480[] 2412/3480[] 2716/3480[] 3048/3480[] 3480/3480[4/4] Building fresh packages...
# success Saved lockfile.
# Done in 7.82s.
# yarn run v1.22.22
# $ craco build
# (node:22549) [DEP0176] DeprecationWarning: fs.F_OK is deprecated, use fs.constants.F_OK instead
# (Use `node --trace-deprecation ...` to show where the warning was created)
# Creating an optimized production build...
# Browserslist: caniuse-lite is outdated. Please run:
#   npx update-browserslist-db@latest
#   Why you should do it regularly: https://github.com/browserslist/update-db#readme
# Browserslist: caniuse-lite is outdated. Please run:
#   npx update-browserslist-db@latest
#   Why you should do it regularly: https://github.com/browserslist/update-db#readme
# Compiled successfully.
#
# File sizes after gzip:
#
#   1.15 MB    build/static/js/748.b2400262.chunk.js
#   700.84 kB  build/static/js/dicomMicroscopyViewer.min.js
#   102.57 kB  build/static/js/main.93037a91.js
#   73.12 kB   build/static/css/808.25d876da.chunk.css
#   71.59 kB   build/static/css/912.c78c3af2.chunk.css
#   71.51 kB   build/static/js/dataLoader.worker.min.js
#   45.33 kB   build/static/js/639.1a7fcfb2.chunk.js
#   263 B      build/static/css/main.e6c13ad2.css
#   179 B      build/static/js/808.16769550.chunk.js
#   179 B      build/static/js/912.c8e83508.chunk.js
#
# The bundle size is significantly larger than recommended.
# Consider reducing it with code splitting: https://goo.gl/9VhYWB
# You can also analyze the project dependencies: https://goo.gl/LeUzfb
#
# The project was built assuming it is hosted at /.
# You can control this with the homepage field in your package.json.
#
# The build folder is ready to be deployed.
# You may serve it with a static server:
#
#   yarn global add serve
#   serve -s build
#
# Find out more about deployment here:
#
#   https://cra.link/deployment
#
# Done in 90.81s.
# Already logged in as nilsroemer@yahoo.com
# Go to the following link in your browser, and complete the sign-in prompts:
#
#     https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=32555940559.apps.googleusercontent.com&redirect_uri=https%3A%2F%2Fsdk.cloud.google.com%2Fauthcode.html&scope=openid+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fuserinfo.email+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcloud-platform+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fappengine.admin+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fsqlservice.login+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcompute+https%3A%2F%2Fwww.googleapis.com%2Fauth%2Faccounts.reauth&state=VvlGJuNOnviZbRkSZj5OaJHnUD1hS7&prompt=consent&token_usage=remote&access_type=offline&code_challenge=Zt0TeA8RaQf5DrLQQvaHLNenyGquhiFFVVEDsPimwQM&code_challenge_method=S256
#
# Once finished, enter the verification code provided in your browser: 4/0AVGzR1DJCd3CQtC7idjqoFFJn_kDs4pDuoBbAiDU963lts3XUWbhqeS1y-6IUP9BKjvkfQ
#
# You are now logged in as [nilsroemer@yahoo.com].
# Your current project is [synlab-pacs-workflow].  You can change this setting by running:
#   $ gcloud config set project PROJECT_ID
# Updated property [core/project].
# synlab-pacs-workflow
# ⠋ Preparing the list of your Firebase projects⠙ Preparing the list of your Firebase projects⠹ Preparing the list of your Firebase projects⠸ Preparing the list of your Firebase projects✔ Preparing the list of your Firebase projects
# ┌─────────────────────────┬─────────────────────────┬────────────────┬──────────────────────┐
# │ Project Display Name    │ Project ID              │ Project Number │ Resource Location ID │
# ├─────────────────────────┼─────────────────────────┼────────────────┼──────────────────────┤
# │ synlab-pacs-slim-viewer │ synlab-pacs-slim-viewer │ 584538855378   │ [Not specified]      │
# └─────────────────────────┴─────────────────────────┴────────────────┴──────────────────────┘
#
# 1 project(s) total.
# Now using project synlab-pacs-slim-viewer
#
# === Deploying to 'synlab-pacs-slim-viewer'...
#
# i  deploying hosting
# i  hosting[synlab-pacs-slim-viewer]: beginning deploy...
# i  hosting[synlab-pacs-slim-viewer]: found 41 files in build
# ⠋ ⠙ ⠹ ⠸  hosting: hashing files [25/41] (60%)⠼  hosting: hashing files [25/41] (60%)⠴  hosting: hashing files [34/41] (82%)⠦  hosting: hashing files [34/41] (82%)⠧  hosting: hashing files [34/41] (82%)⠇  hosting: hashing files [37/41] (90%)⠏  hosting: hashing files [37/41] (90%)⠋  hosting: hashing files [38/41] (92%)⠙  hosting: hashing files [38/41] (92%)⠹  hosting: hashing files [38/41] (92%)⠸  hosting: hashing files [39/41] (95%)⠼  hosting: hashing files [39/41] (95%)⠴  hosting: hashing files [39/41] (95%)⠦  hosting: hashing files [39/41] (95%)⠧  hosting: hashing files [39/41] (95%)⠇  hosting: hashing files [40/41] (97%)⠏  hosting: hashing files [40/41] (97%)⠋  hosting: hashing files [40/41] (97%)⠙  hosting: hashing files [40/41] (97%)⠹  hosting: hashing files [40/41] (97%)⠸  hosting: hashing files [40/41] (97%)⠼  hosting: hashing files [40/41] (97%)⠴  hosting: uploading new files [0/1] (0%)⠦  hosting: uploading new files [0/1] (0%)⠧  hosting: uploading new files [0/1] (0%)⠇  hosting: uploading new files [0/1] (0%)⠏  hosting: uploading new files [0/1] (0%)⠋  hosting: uploading new files [0/1] (0%)⠙  hosting: uploading new files [0/1] (0%)⠹  hosting: uploading new files [0/1] (0%)⠸  hosting: uploading new files [0/1] (0%)⠼  hosting: uploading new files [0/1] (0%)✔  hosting[synlab-pacs-slim-viewer]: file upload complete
# i  hosting[synlab-pacs-slim-viewer]: finalizing version...
# ✔  hosting[synlab-pacs-slim-viewer]: version finalized
# i  hosting[synlab-pacs-slim-viewer]: releasing new version...
# ✔  hosting[synlab-pacs-slim-viewer]: release complete
#
# ✔  Deploy complete!
#
# Project Console: https://console.firebase.google.com/project/synlab-pacs-slim-viewer/overview
# Hosting URL: https://synlab-pacs-slim-viewer.web.app
